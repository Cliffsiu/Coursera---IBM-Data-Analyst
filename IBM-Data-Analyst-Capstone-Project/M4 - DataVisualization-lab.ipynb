# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# your code goes here

qu = '''
SELECT ConvertedComp
FROM master;
'''
pd.read_sql_query(qu,conn).plot(kind='hist')
#df['ConvertedComp'].plot(kind='hist')
plt.title('Counting Converted Comp')
plt.xlabel('Converted Comp')
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
qu = '''
SELECT Age
FROM master;
'''
pd.read_sql_query(qu,conn).plot(kind='box')
plt.title('Box plot of Age')
plt.ylabel('Total')
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
qu = '''
SELECT Age, WorkWeekHrs
FROM master;
'''
df = pd.read_sql_query(qu,conn)
print(df[['Age','WorkWeekHrs']].corr())

plt.scatter(x=df['Age'],y=df['WorkWeekHrs'])
plt.title('Relationship between Age and Weekly woking hours')
plt.xlabel('Age')
plt.ylabel('WorkWeekHrs')
plt.show()
# Out:
#                   Age  WorkWeekHrs
# Age          1.000000     0.036517
# WorkWeekHrs  0.036517     1.000000

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
qu = '''
SELECT Age, WorkWeekHrs, CodeRevhrs
FROM master;
'''
df = pd.read_sql_query(qu,conn)


sns.scatterplot(data=df, x="WorkWeekHrs", y="CodeRevHrs", size="Age", alpha=0.5, sizes=(10, 500))
plt.title('Relationship between WorkWeekHrs and CodeRevHrs')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
qu = """ 
SELECT DatabaseDesireNextYear, COUNT(*) AS count
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY count DESC LIMIT 5;
""" 

df = pd.read_sql_query(qu,conn)
df.set_index('DatabaseDesireNextYear', inplace=True) 
df['count'].plot(kind='pie', autopct='%1.1f%%',labels=None, startangle=90, shadow=True, pctdistance=1.12)
plt.legend(labels=df.index, loc='upper right', bbox_to_anchor=(1.45, 1))
plt.title('Top 5 Databases Respondents Wish To Learn') 
plt.ylabel('')
plt.show()

# %%
# Language Desire Next Year
qu = """ 
SELECT LanguageDesireNextYear,  COUNT(*) as count
FROM LanguageDesireNextYear
GROUP BY LanguageDesireNextYear
ORDER BY count DESC;

""" 

df = pd.read_sql_query(qu,conn)
df.head()
# Out:
#   LanguageDesireNextYear  count
# 0             JavaScript   6630
# 1               HTML/CSS   5328
# 2                 Python   5239
# 3                    SQL   5012
# 4             TypeScript   4088

# %%
# language Currently working with
qu = """ 
SELECT *
FROM LanguageWorkedWith
""" 

df = pd.read_sql_query(qu,conn)
df.groupby('LanguageWorkedWith').size().reset_index(name='Count').sort_values('Count', ascending=False).head()
# Out:
#        LanguageWorkedWith  Count
# 13             JavaScript   8687
# 11               HTML/CSS   7830
# 22                    SQL   7106
# 1   Bash/Shell/PowerShell   4642
# 18                 Python   4542

# %%
# language Currently only working on mysql
qu = """ 
SELECT *
FROM DatabaseWorkedWith
""" 
df = pd.read_sql_query(qu,conn)
df.groupby('Respondent').filter(lambda x: len(x) == 1)['DatabaseWorkedWith'].value_counts()
# Out:
# Microsoft SQL Server    845
# MySQL                   474
# PostgreSQL              351
# SQLite                  192
# MongoDB                 170
# Oracle                  162
# Other(s):                94
# Firebase                 90
# MariaDB                  44
# DynamoDB                 28
# Elasticsearch            27
# Redis                    20
# Cassandra                10
# Couchbase                 8
# Name: DatabaseWorkedWith, dtype: int64

# %%
qu = """ 
SELECT *
FROM DevType
""" 
df = pd.read_sql_query(qu,conn)
df['DevType'].value_counts()
# Out:
# Developer, full-stack                            6928
# Developer, back-end                              6290
# Developer, front-end                             3920
# Developer, desktop or enterprise applications    2575
# Developer, mobile                                1959
# DevOps specialist                                1639
# Database administrator                           1413
# System administrator                             1202
# Designer                                          988
# Developer, QA or test                             911
# Developer, embedded applications or devices       854
# Engineer, data                                    832
# Data scientist or machine learning specialist     803
# Data or business analyst                          802
# Student                                           766
# Academic researcher                               556
# Educator                                          514
# ...

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here
qu = """ 
SELECT WorkWeekHrs, CodeRevHrs, Age
FROM master
WHERE Age BETWEEN 30 AND 35;
""" 
df = pd.read_sql_query(qu,conn)
df1 = df.groupby('Age').median()
df1.plot(kind='bar', figsize=(10, 6), stacked=True)
plt.legend(bbox_to_anchor=(1.25, 1))
plt.title('Stacked of median WorkWeekHrs and CodeRevHrs')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
qu = """ 
SELECT ConvertedComp, Age
FROM master
WHERE Age BETWEEN 45 AND 60;
""" 
df = pd.read_sql_query(qu,conn)
df1 = df.groupby('Age').median()
df1.plot(kind='line', figsize=(10, 6))
plt.title('Stacked of median age and ConvertedComp')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
qu = """ 
SELECT MainBranch, COUNT(*) AS count
FROM master
GROUP BY MainBranch;
""" 
df = pd.read_sql_query(qu,conn)
df.plot(kind='barh', figsize=(10, 6))
plt.title('Horizontal bar chart of Main Branch')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
